# %%
import numpy as np
import pandas as pd
# Out:
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
IC50_AUC_SMILES = pd.read_csv("./data/IC50_AUC_SMILES_final_train.csv")
IC50_AUC_SMILES
# Out:
#         CellLineID                                             smiles  \
# 0       ACH-000001  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 1       ACH-000001  CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...
# 2       ACH-000001                             N.N.[Cl-].[Cl-].[Pt+2]
# 3       ACH-000001  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...
# 4       ACH-000001  COC1=C(C=C2C(=C1)N=CN=C2NC3=CC(=C(C=C3)F)Cl)OC...
# ...            ...                                                ...
# 117641  ACH-002317  C1COCCN1C2=CC=C(C=C2)C3=C(C=NC=C3)C4=CC(=C(C(=...
# 117642  ACH-002317  CC1CN(CC(N1)C)C2=NC=C(C(=C2)C)C3=CC=C(C=C3)C4=...
# 117643  ACH-002317  CC1CN(CC(N1)C)C2=NC=C(C(=C2)C)C3=CC=C(C=C3)C4=...
# 117644  ACH-002317  C1CC(C1)NC2=NC=CC(=C2)C(=O)NCC(CN3CCC4=CC=CC=C...
# 117645  ACH-002317      C1=CC(=CC=C1C2=CNN=C2)C(CN)(C3=CC=C(C=C3)Cl)O
#
#              AUC     IC50
# 0       0.967187      NaN
# 1       0.666062      NaN
# 2       0.977907      NaN
# 3       0.922989      NaN
# 4       0.957586      NaN
# ...          ...      ...
# 117641  0.926422      NaN
# 117642       NaN  3.25832
# 117643  0.916274      NaN
# 117644  0.906540      NaN
# 117645  0.996681      NaN
#
# [117646 rows x 4 columns]

# %%
metabolomics = pd.read_csv("./data/Metabolomics_subsetted.csv")
metabolomics = metabolomics.rename(columns={metabolomics.columns[0]: "CellLineID"})
metabolomics
# Out:
#      CellLineID  2-aminoadipate  3-phosphoglycerate  alpha-glycerophosphate  \
# 0    ACH-000698        6.112727            6.034198                5.896896
# 1    ACH-000489        5.577413            5.727045                5.111468
# 2    ACH-000431        5.886398            5.574881                5.541259
# 3    ACH-000707        5.770030            6.099229                6.233259
# 4    ACH-000509        5.480683            5.469742                6.509397
# ..          ...             ...                 ...                     ...
# 922  ACH-000655        5.977636            6.026483                6.480536
# 923  ACH-000273        5.957233            6.090834                5.323475
# 924  ACH-000504        5.967707            5.931487                5.620542
# 925  ACH-000825        5.962415            5.992640                6.296222
# 926  ACH-000084        6.332344            5.812531                5.446330
#
#      4-pyridoxate  aconitate   adenine   adipate  alpha-ketoglutarate  \
# 0        6.000532   5.513618  5.868529  5.977177             5.693074
# 1        6.073250   5.802494  5.824473  5.888821             5.768379
# 2        5.848375   5.665026  5.875548  5.894904             5.839640
# 3        5.543495   5.767759  6.155905  6.111148             5.949481
# 4        6.251005   5.190578  5.897085  6.148333             5.607481
# ..            ...        ...       ...       ...                  ...
# 922      6.112056   5.878324  5.732508  5.981183             6.459139
# 923      6.145795   5.741201  5.605435  6.184192             6.004195
# 924      5.955261   5.935244  5.384674  5.955886             6.239657
# 925      5.916386   6.043984  5.883976  5.954731             6.181054
# 926      6.469052   5.501232  6.469954  6.136017             5.479015
#
#           AMP  ...  C56:8 TAG  C56:7 TAG  C56:6 TAG  C56:5 TAG  C56:4 TAG  \
# 0    5.923737  ...   6.070239   6.133433   6.091089   6.257711   6.372732
# 1    5.760784  ...   6.248653   6.633575   6.378052   6.341043   6.360945
# 2    5.742613  ...   5.942887   5.946988   5.837980   5.913350   6.137530
# 3    6.342703  ...   6.516922   6.113791   6.282113   6.248667   6.109480
# 4    5.871600  ...   6.161981   6.777932   6.676390   6.695659   6.751029
# ..        ...  ...        ...        ...        ...        ...        ...
# 922  5.642855  ...   5.547818   5.703861   5.581725   5.506887   5.362247
# 923  5.663866  ...   5.713210   5.651439   5.720680   5.387960   5.275798
# 924  5.527619  ...   5.605403   5.317500   5.630315   5.433324   5.330957
# 925  5.820966  ...   5.949798   6.249271   6.248746   6.130000   5.873297
# 926  5.694210  ...   6.588558   6.548211   6.667652   6.868391   6.598519
#
#      C56:3 TAG  C56:2 TAG  C58:8 TAG  C58:7 TAG  C58:6 TAG
# 0     6.202511   5.939576   6.309821   6.115974   5.999436
# 1     6.333540   6.137271   7.065858   6.832174   6.363064
# 2     5.807546   5.704149   5.881193   5.785208   5.504225
# 3     6.043570   5.846802   6.429402   5.779815   6.241530
# 4     6.385056   6.682612   6.757899   6.728570   6.879260
# ..         ...        ...        ...        ...        ...
# 922   5.322091   5.556126   5.544802   4.897559   5.506999
# 923   5.289684   5.494241   5.533795   5.139488   5.452544
# 924   5.481404   5.570553   5.146598   5.010639   5.114385
# 925   5.826041   5.997694   6.411166   6.105394   6.387275
# 926   5.956474   6.022471   6.862916   7.045115   6.841075
#
# [927 rows x 226 columns]

# %%
df_merged = pd.merge(IC50_AUC_SMILES, metabolomics, left_on='CellLineID', right_on='CellLineID', how='inner')

# %%
df_merged
# Out:
#        CellLineID                                             smiles  \
# 0      ACH-000001  CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 1      ACH-000001  CCC1(CC2CC(C3=C(CCN(C2)C1)C4=CC=CC=C4N3)(C5=C(...
# 2      ACH-000001                             N.N.[Cl-].[Cl-].[Pt+2]
# 3      ACH-000001  CC1=C2C(C(=O)C3(C(CC4C(C3C(C(C2(C)C)(CC1OC(=O)...
# 4      ACH-000001  COC1=C(C=C2C(=C1)N=CN=C2NC3=CC(=C(C=C3)F)Cl)OC...
# ...           ...                                                ...
# 81302  ACH-001307  CC1=CN=C(N=C1C2=CNC(=C2)C(=O)NC(CO)C3=CC(=CC=C...
# 81303  ACH-001307  CN1C(=C(C=N1)Cl)C2=C(OC(=C2)C(=O)NC(CC3=CC(=C(...
# 81304  ACH-001307  CC1CN(CC(N1)C)C2=NC=C(C(=C2)C)C3=CC=C(C=C3)C4=...
# 81305  ACH-001307  CC1CN(CC(N1)C)C2=NC=C(C(=C2)C)C3=CC=C(C=C3)C4=...
# 81306  ACH-001307  C1CC(C1)NC2=NC=CC(=C2)C(=O)NCC(CN3CCC4=CC=CC=C...
#
#             AUC      IC50  2-aminoadipate  3-phosphoglycerate  \
# 0      0.967187       NaN        6.067403            5.602360
# 1      0.666062       NaN        6.067403            5.602360
# 2      0.977907       NaN        6.067403            5.602360
# 3      0.922989       NaN        6.067403            5.602360
# 4      0.957586       NaN        6.067403            5.602360
# ...         ...       ...             ...                 ...
# 81302  0.894145       NaN        6.558230            5.647197
# 81303  0.975099       NaN        6.558230            5.647197
# 81304       NaN  2.428133        6.558230            5.647197
# 81305  0.892960       NaN        6.558230            5.647197
# 81306  0.912144       NaN        6.558230            5.647197
#
#        alpha-glycerophosphate  4-pyridoxate  aconitate   adenine  ...  \
# 0                    5.556346      5.637666   6.040375  5.649284  ...
# 1                    5.556346      5.637666   6.040375  5.649284  ...
# 2                    5.556346      5.637666   6.040375  5.649284  ...
# 3                    5.556346      5.637666   6.040375  5.649284  ...
# 4                    5.556346      5.637666   6.040375  5.649284  ...
# ...                       ...           ...        ...       ...  ...
# 81302                6.319460      6.153176   6.239952  5.836617  ...
# 81303                6.319460      6.153176   6.239952  5.836617  ...
# 81304                6.319460      6.153176   6.239952  5.836617  ...
# 81305                6.319460      6.153176   6.239952  5.836617  ...
# 81306                6.319460      6.153176   6.239952  5.836617  ...
#
#        C56:8 TAG  C56:7 TAG  C56:6 TAG  C56:5 TAG  C56:4 TAG  C56:3 TAG  \
# 0       5.945463   6.133054   6.177007   6.136944   5.899146   5.373586
# 1       5.945463   6.133054   6.177007   6.136944   5.899146   5.373586
# 2       5.945463   6.133054   6.177007   6.136944   5.899146   5.373586
# 3       5.945463   6.133054   6.177007   6.136944   5.899146   5.373586
# 4       5.945463   6.133054   6.177007   6.136944   5.899146   5.373586
# ...          ...        ...        ...        ...        ...        ...
# 81302   5.535541   6.008684   5.820675   5.555397   5.773193   5.782641
# 81303   5.535541   6.008684   5.820675   5.555397   5.773193   5.782641
# 81304   5.535541   6.008684   5.820675   5.555397   5.773193   5.782641
# 81305   5.535541   6.008684   5.820675   5.555397   5.773193   5.782641
# 81306   5.535541   6.008684   5.820675   5.555397   5.773193   5.782641
#
#        C56:2 TAG  C58:8 TAG  C58:7 TAG  C58:6 TAG
# 0       5.608323   6.338148   6.264488   5.858530
# 1       5.608323   6.338148   6.264488   5.858530
# 2       5.608323   6.338148   6.264488   5.858530
# 3       5.608323   6.338148   6.264488   5.858530
# 4       5.608323   6.338148   6.264488   5.858530
# ...          ...        ...        ...        ...
# 81302   5.960382   5.650787   5.518399   5.701732
# 81303   5.960382   5.650787   5.518399   5.701732
# 81304   5.960382   5.650787   5.518399   5.701732
# 81305   5.960382   5.650787   5.518399   5.701732
# 81306   5.960382   5.650787   5.518399   5.701732
#
# [81307 rows x 229 columns]

# %%
df_merged.to_csv("./train_data/metabolomics.csv", index=False)
